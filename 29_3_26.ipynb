# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A510F7/TRAINING/blob/main/29_3_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# BUBBLE SORT
#
# TIME COMPLEXITY:no.of comparisons+no.of swaps=(N^2)
# bestcase-o(n)

# %%
def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n-i-1):
            if arr[j] > arr[j+1]:
                # swap
                arr[j], arr[j+1] = arr[j+1], arr[j]
    return arr

# Example
numbers = [70,50,25,1,12,3,55,72,67]
sorted_numbers = bubble_sort(numbers)
print("Sorted array:", sorted_numbers)
# Out:
# Sorted array: [1, 3, 12, 25, 50, 55, 67, 70, 72]

# %% [markdown]
# SELECTION SORT
#
# TIME COMPLEXITY:O(N^2)

# %%
def selection_sort(arr):
    n = len(arr)
    for i in range(n):
        min_idx = i  # Assume the current element is the minimum
        for j in range(i + 1, n):
            if arr[j] < arr[min_idx]:  # Find the actual minimum element in the unsorted part
                min_idx = j
        # Swap the found minimum element with the element at the current position 'i'
        arr[i], arr[min_idx] = arr[min_idx], arr[i]
    return arr

# Example
numbers = [70,50,25,1,12,3,55,72,67]
sorted_numbers = selection_sort(numbers)
print("Sorted array:", sorted_numbers)
# Out:
# Sorted array: [1, 3, 12, 25, 50, 55, 67, 70, 72]

# %% [markdown]
# INSERTION SORT
#
# big-o(n^2)
# big-o(n)(bestcase)

# %%
def insertion_sort(arr):
    for i in range(1, len(arr)):
        key = arr[i]
        j = i - 1
        while j >= 0 and arr[j] > key:
            arr[j + 1] = arr[j]
            j -= 1
        arr[j + 1] = key
    return arr
numbers = [5, 2, 9, 1, 5, 6]
insertion_sort(numbers)
print("Sorted array:", numbers)
# Out:
# Sorted array: [1, 2, 5, 5, 6, 9]
